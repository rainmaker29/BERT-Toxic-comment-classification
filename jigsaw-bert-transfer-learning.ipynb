# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bert-pytorch-from-yuval/pytorch_model.bin
# /kaggle/input/bert-pytorch-from-yuval/bert_pytorch.bin
# /kaggle/input/bert-pytorch-from-yuval/bert_config.json
# /kaggle/input/bert-pretrained-models/cased_L-12_H-768_A-12/cased_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/cased_L-12_H-768_A-12/cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/cased_L-12_H-768_A-12/cased_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/cased_L-12_H-768_A-12/cased_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/cased_L-12_H-768_A-12/cased_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/cased_l-12_h-768_a-12/cased_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/cased_l-12_h-768_a-12/cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/cased_l-12_h-768_a-12/cased_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/cased_l-12_h-768_a-12/cased_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/cased_l-12_h-768_a-12/cased_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/multi_cased_l-12_h-768_a-12/multi_cased_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/multi_cased_l-12_h-768_a-12/multi_cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/multi_cased_l-12_h-768_a-12/multi_cased_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/multi_cased_l-12_h-768_a-12/multi_cased_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/multi_cased_l-12_h-768_a-12/multi_cased_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/uncased_l-24_h-1024_a-16/uncased_L-24_H-1024_A-16/vocab.txt
# /kaggle/input/bert-pretrained-models/uncased_l-24_h-1024_a-16/uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/uncased_l-24_h-1024_a-16/uncased_L-24_H-1024_A-16/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/uncased_l-24_h-1024_a-16/uncased_L-24_H-1024_A-16/bert_config.json
# /kaggle/input/bert-pretrained-models/uncased_l-24_h-1024_a-16/uncased_L-24_H-1024_A-16/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/uncased_L-12_H-768_A-12/uncased_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/uncased_L-12_H-768_A-12/uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/uncased_L-12_H-768_A-12/uncased_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/uncased_L-12_H-768_A-12/uncased_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/uncased_L-12_H-768_A-12/uncased_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/chinese_l-12_h-768_a-12/chinese_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/chinese_l-12_h-768_a-12/chinese_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/chinese_l-12_h-768_a-12/chinese_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/chinese_l-12_h-768_a-12/chinese_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/chinese_l-12_h-768_a-12/chinese_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/uncased_l-12_h-768_a-12/uncased_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/uncased_l-12_h-768_a-12/uncased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/uncased_l-12_h-768_a-12/uncased_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/uncased_l-12_h-768_a-12/uncased_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/uncased_l-12_h-768_a-12/uncased_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/cased_l-24_h-1024_a-16/cased_L-24_H-1024_A-16/vocab.txt
# /kaggle/input/bert-pretrained-models/cased_l-24_h-1024_a-16/cased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/cased_l-24_h-1024_a-16/cased_L-24_H-1024_A-16/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/cased_l-24_h-1024_a-16/cased_L-24_H-1024_A-16/bert_config.json
# /kaggle/input/bert-pretrained-models/cased_l-24_h-1024_a-16/cased_L-24_H-1024_A-16/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/chinese_L-12_H-768_A-12/chinese_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/chinese_L-12_H-768_A-12/chinese_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/chinese_L-12_H-768_A-12/chinese_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/chinese_L-12_H-768_A-12/chinese_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/chinese_L-12_H-768_A-12/chinese_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/uncased_L-24_H-1024_A-16/uncased_L-24_H-1024_A-16/vocab.txt
# /kaggle/input/bert-pretrained-models/uncased_L-24_H-1024_A-16/uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/uncased_L-24_H-1024_A-16/uncased_L-24_H-1024_A-16/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/uncased_L-24_H-1024_A-16/uncased_L-24_H-1024_A-16/bert_config.json
# /kaggle/input/bert-pretrained-models/uncased_L-24_H-1024_A-16/uncased_L-24_H-1024_A-16/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/multi_cased_L-12_H-768_A-12/multi_cased_L-12_H-768_A-12/vocab.txt
# /kaggle/input/bert-pretrained-models/multi_cased_L-12_H-768_A-12/multi_cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/multi_cased_L-12_H-768_A-12/multi_cased_L-12_H-768_A-12/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/multi_cased_L-12_H-768_A-12/multi_cased_L-12_H-768_A-12/bert_config.json
# /kaggle/input/bert-pretrained-models/multi_cased_L-12_H-768_A-12/multi_cased_L-12_H-768_A-12/bert_model.ckpt.index
# /kaggle/input/bert-pretrained-models/cased_L-24_H-1024_A-16/cased_L-24_H-1024_A-16/vocab.txt
# /kaggle/input/bert-pretrained-models/cased_L-24_H-1024_A-16/cased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
# /kaggle/input/bert-pretrained-models/cased_L-24_H-1024_A-16/cased_L-24_H-1024_A-16/bert_model.ckpt.meta
# /kaggle/input/bert-pretrained-models/cased_L-24_H-1024_A-16/cased_L-24_H-1024_A-16/bert_config.json
# /kaggle/input/bert-pretrained-models/cased_L-24_H-1024_A-16/cased_L-24_H-1024_A-16/bert_model.ckpt.index
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-unintended-bias-train.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/test-processed-seqlen128.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-toxic-comment-train.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-toxic-comment-train-processed-seqlen128.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-unintended-bias-train-processed-seqlen128.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv
# /kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation-processed-seqlen128.csv
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/requirements.txt
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/MANIFEST.in
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.gitignore
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/LICENSE
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/README.md
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/setup.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/packed-refs
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/config
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/index
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/description
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/objects/pack/pack-7d13e115aba5393271309bcba351fc1fb5c6f728.idx
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/objects/pack/pack-7d13e115aba5393271309bcba351fc1fb5c6f728.pack
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/logs/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/logs/refs/heads/master
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/refs/heads/master
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/refs/remotes/origin/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/pre-push.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/update.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/post-update.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/pre-applypatch.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/commit-msg.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/pre-commit.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/pre-rebase.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/hooks/applypatch-msg.sample
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.git/info/exclude
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/modeling_transfo_xl_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/tokenization_openai_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/tokenization_transfo_xl_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/optimization_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/tokenization_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/modeling_gpt2_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/modeling_openai_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/modeling_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/tests/tokenization_gpt2_test.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/samples/input.txt
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/samples/sample_text.txt
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/docker/Dockerfile
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.circleci/config.yml
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/run_gpt2.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/run_classifier.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/run_squad.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/run_openai_gpt.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/extract_features.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/run_transfo_xl.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/run_swag.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/lm_finetuning/pregenerate_training_data.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/lm_finetuning/finetune_on_pregenerated.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/lm_finetuning/README.md
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/examples/lm_finetuning/simple_lm_finetuning.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/notebooks/Comparing-TF-and-PT-models-SQuAD.ipynb
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/notebooks/Comparing-TF-and-PT-models.ipynb
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/notebooks/Comparing-TF-and-PT-models-MLM-NSP.ipynb
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_transfo_xl_utilities.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization_gpt2.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_tf_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_gpt2_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization_transfo_xl.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_gpt2.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_transfo_xl_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_openai.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/__main__.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization_openai.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/optimization.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/optimization_openai.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_openai_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/__init__.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_transfo_xl.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/pytorch_pretrained_bert/file_utils.py
# /kaggle/input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT/.github/stale.yml
# /kaggle/input/ppbert/pytorch-pretrained-BERT/requirements.txt
# /kaggle/input/ppbert/pytorch-pretrained-BERT/MANIFEST.in
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.gitignore
# /kaggle/input/ppbert/pytorch-pretrained-BERT/LICENSE
# /kaggle/input/ppbert/pytorch-pretrained-BERT/README.md
# /kaggle/input/ppbert/pytorch-pretrained-BERT/setup.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/packed-refs
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/config
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/index
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/description
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/objects/pack/pack-7d13e115aba5393271309bcba351fc1fb5c6f728.idx
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/objects/pack/pack-7d13e115aba5393271309bcba351fc1fb5c6f728.pack
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/logs/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/logs/refs/heads/master
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/refs/heads/master
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/refs/remotes/origin/HEAD
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/pre-push.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/update.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/post-update.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/pre-applypatch.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/commit-msg.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/pre-commit.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/pre-rebase.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/hooks/applypatch-msg.sample
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.git/info/exclude
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/modeling_transfo_xl_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/tokenization_openai_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/tokenization_transfo_xl_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/optimization_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/tokenization_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/modeling_gpt2_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/modeling_openai_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/modeling_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/tests/tokenization_gpt2_test.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/samples/input.txt
# /kaggle/input/ppbert/pytorch-pretrained-BERT/samples/sample_text.txt
# /kaggle/input/ppbert/pytorch-pretrained-BERT/docker/Dockerfile
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.circleci/config.yml
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/run_gpt2.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/run_classifier.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/run_squad.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/run_openai_gpt.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/extract_features.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/run_transfo_xl.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/run_swag.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/lm_finetuning/pregenerate_training_data.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/lm_finetuning/finetune_on_pregenerated.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/lm_finetuning/README.md
# /kaggle/input/ppbert/pytorch-pretrained-BERT/examples/lm_finetuning/simple_lm_finetuning.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/notebooks/Comparing-TF-and-PT-models-SQuAD.ipynb
# /kaggle/input/ppbert/pytorch-pretrained-BERT/notebooks/Comparing-TF-and-PT-models.ipynb
# /kaggle/input/ppbert/pytorch-pretrained-BERT/notebooks/Comparing-TF-and-PT-models-MLM-NSP.ipynb
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_transfo_xl_utilities.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization_gpt2.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_tf_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_gpt2_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization_transfo_xl.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_gpt2.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_transfo_xl_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_openai.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/__main__.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/tokenization_openai.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/optimization.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/optimization_openai.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/convert_openai_checkpoint_to_pytorch.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/__init__.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling_transfo_xl.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/modeling.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/pytorch_pretrained_bert/file_utils.py
# /kaggle/input/ppbert/pytorch-pretrained-BERT/.github/stale.yml

# %%
from __future__ import absolute_import,division,print_function
import torch.utils.data
from tqdm import tqdm
import warnings
warnings.filterwarnings(action='once')
device = torch.device('cuda')

# %%
import sys
package_dir = "../input/ppbert/pytorch-pretrained-bert/pytorch-pretrained-BERT"
sys.path.append(package_dir)

from pytorch_pretrained_bert import BertTokenizer,BertForSequenceClassification,BertAdam,BertConfig

# %%
def convert_lines(example,max_seq_length,tokenizer):
    max_seq_length -= 2
    all_tokens = []
    longer = 0
    for text in tqdm(example):
        tokens_a = tokenizer.tokenize(text)
        if len(tokens_a)>max_seq_length:
            tokens_a = tokens_a[:max_seq_length]
            longer +=1
        one_token = tokenizer.convert_tokens_to_ids(["[CLS]"] + tokens_a + ["[SEP]"] 
                                                   )+[0] * (max_seq_length - len(tokens_a))
        all_tokens.append(one_token)
        
    return np.array(all_tokens)

# %%
max_seq_len = 220
seed = 1234
batch_size = 32
bert_model_path = '../input/bert-pytorch-from-yuval/'
BERT_MODEL_PATH = '../input/bert-pretrained-models/uncased_l-12_h-768_a-12/uncased_L-12_H-768_A-12/'

# %%
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

bert_config = BertConfig(bert_model_path+'bert_config.json')
tokenizer = BertTokenizer.from_pretrained(BERT_MODEL_PATH, cache_dir=None,do_lower_case=True)

# %%
test_df["content"].fillna("DUMMY_VALUE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ab76ce95eea0> in <module>
# ----> 1 test_df["content"].fillna("DUMMY_VALUE")
#
# NameError: name 'test_df' is not defined

# %%
test_df = pd.read_csv("../input/jigsaw-multilingual-toxic-comment-classification/test.csv")
test_df['content'] = test_df['content'].astype(str) 
X_test = convert_lines(test_df["content"].fillna("DUMMY_VALUE"), max_seq_len, tokenizer)
# Out:
# 100%|██████████| 63812/63812 [02:49<00:00, 375.60it/s]

# %%
model = BertForSequenceClassification(bert_config,num_labels=1)
model.load_state_dict(torch.load("../input/bert-pytorch-from-yuval/bert_pytorch.bin"))
model.to(device)
for param in model.parameters():
    param.requires_grad = False
model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): BertLayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=1, bias=True)
# )

# %%
test_preds = np.zeros((len(X_test)))
test = torch.utils.data.TensorDataset(torch.tensor(X_test, dtype=torch.long))
test_loader = torch.utils.data.DataLoader(test, batch_size=32, shuffle=False)
tk0 = tqdm(test_loader)
for i, (x_batch,) in enumerate(tk0):
    pred = model(x_batch.to(device), attention_mask=(x_batch > 0).to(device), labels=None)
    test_preds[i * 32:(i + 1) * 32] = pred[:, 0].detach().cpu().squeeze().numpy()

test_pred = torch.sigmoid(torch.tensor(test_preds)).numpy().ravel()
# Out:
# 100%|██████████| 1995/1995 [07:36<00:00,  4.37it/s]

# %%
submission = pd.DataFrame.from_dict({
    'id': test_df['id'],
    'toxic': test_pred
})
submission.to_csv('/kaggle/working/submission.csv', index=False)

# %%
submission.head()
# Out:
#    id     toxic
# 0   0  0.005487
# 1   1  0.002618
# 2   2  0.002360
# 3   3  0.001554
# 4   4  0.001493
